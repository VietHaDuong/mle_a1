# %%
import pandas as pd 
import numpy as np

# %%
fa = pd.read_csv('data/features_attributes.csv')
fc = pd.read_csv('data/feature_clickstream.csv')
ff = pd.read_csv('data/features_financials.csv')
lms = pd.read_csv('data/lms_loan_daily.csv')
fa.describe()
# Out:
#        Customer_ID    Name    Age        SSN Occupation snapshot_date
# count        12500   12500  12500      12500      12500         12500
# unique       12500   10139    301      11798         16            25
# top     CUS_0x1000  Langep     26  #F%$D@*&8    _______    2024-08-01
# freq             1       6    364        703        880           543

# %%
print('===== Raw CSV Dtypes =====')
print('\n--- Features Attributes ---')
print(fa.dtypes)
print('\n--- Features Financials ---')
print(ff.dtypes)
print('\n--- LMS Loan Daily ---')
print(lms.dtypes)
print('\n--- Feature Clickstream ---')
print(fc.dtypes)
# Out:
# ===== Raw CSV Dtypes =====
#
# --- Features Attributes ---
# Customer_ID      str
# Name             str
# Age              str
# SSN              str
# Occupation       str
# snapshot_date    str
# dtype: object
#
# --- Features Financials ---
# Customer_ID                     str
# Annual_Income                   str
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                     str
# Type_of_Loan                    str
# Delay_from_due_date           int64
# Num_of_Delayed_Payment          str
# Changed_Credit_Limit            str
# Num_Credit_Inquiries        float64
# Credit_Mix                      str
# Outstanding_Debt                str
# Credit_Utilization_Ratio    float64
# Credit_History_Age              str
# Payment_of_Min_Amount           str
# Total_EMI_per_month         float64
# Amount_invested_monthly         str
# Payment_Behaviour               str
# Monthly_Balance                 str
# snapshot_date                   str
# dtype: object
#
# --- LMS Loan Daily ---
# loan_id                str
# Customer_ID            str
# loan_start_date        str
# tenure               int64
# installment_num      int64
# loan_amt             int64
# due_amt            float64
# paid_amt           float64
# overdue_amt        float64
# balance            float64
# snapshot_date          str
# dtype: object
#
# --- Feature Clickstream ---
# fe_1             int64
# fe_2             int64
# fe_3             int64
# fe_4             int64
# fe_5             int64
# fe_6             int64
# fe_7             int64
# fe_8             int64
# fe_9             int64
# fe_10            int64
# fe_11            int64
# fe_12            int64
# fe_13            int64
# fe_14            int64
# fe_15            int64
# fe_16            int64
# fe_17            int64
# fe_18            int64
# fe_19            int64
# fe_20            int64
# Customer_ID        str
# snapshot_date      str
# dtype: object

# %%
print('=====Oldest to Latest date=====')
print()
print('=====Features Attributes=====')
print(fa['snapshot_date'].min())
print(fa['snapshot_date'].max())

print('=====Feature Clickstream=====')
print(fc['snapshot_date'].min())
print(fc['snapshot_date'].max())

print('=====Features Financials=====')
print(ff['snapshot_date'].min())
print(ff['snapshot_date'].max())

print('=====LMS Loan Daily=====')
print(lms['snapshot_date'].min())
print(lms['snapshot_date'].max())
# Out:
# =====Oldest to Latest date=====
#
# =====Features Attributes=====
# 2023-01-01
# 2025-01-01
# =====Feature Clickstream=====
# 2023-01-01
# 2024-12-01
# =====Features Financials=====
# 2023-01-01
# 2025-01-01
# =====LMS Loan Daily=====
# 2023-01-01
# 2025-11-01

# %%
print('Unique Date')
print(100*"=")
print('Features Attributes')
print(fa['snapshot_date'].unique())

print(100*"=")
print('Feature Clickstream')
print(fc['snapshot_date'].unique())

print(100*"=")
print('Features Financials')
print(ff['snapshot_date'].unique())

print(100*"=")
print('LMS Loan Daily')
print(lms['snapshot_date'].unique())
# Out:
# Unique Date
# ====================================================================================================
# Features Attributes
# <StringArray>
# ['2023-05-01', '2025-01-01', '2024-03-01', '2023-11-01', '2023-12-01',
#  '2023-08-01', '2023-10-01', '2024-01-01', '2024-04-01', '2023-01-01',
#  '2024-10-01', '2024-12-01', '2023-06-01', '2024-02-01', '2023-04-01',
#  '2023-09-01', '2024-05-01', '2024-11-01', '2024-09-01', '2023-02-01',
#  '2024-08-01', '2023-03-01', '2024-06-01', '2024-07-01', '2023-07-01']
# Length: 25, dtype: str
# ====================================================================================================
# Feature Clickstream
# <StringArray>
# ['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01',
#  '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01', '2023-10-01',
#  '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#  '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#  '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01']
# Length: 24, dtype: str
# ====================================================================================================
# Features Financials
# <StringArray>
# ['2023-05-01', '2025-01-01', '2024-03-01', '2023-11-01', '2023-12-01',
#  '2023-08-01', '2023-10-01', '2024-01-01', '2024-04-01', '2023-01-01',
#  '2024-10-01', '2024-12-01', '2023-06-01', '2024-02-01', '2023-04-01',
#  '2023-09-01', '2024-05-01', '2024-11-01', '2024-09-01', '2023-02-01',
#  '2024-08-01', '2023-03-01', '2024-06-01', '2024-07-01', '2023-07-01']
# Length: 25, dtype: str
# ====================================================================================================
# LMS Loan Daily
# <StringArray>
# ['2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01', '2023-09-01',
#  '2023-10-01', '2023-11-01', '2023-12-01', '2024-01-01', '2024-02-01',
#  '2024-03-01', '2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#  '2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01', '2025-09-01',
#  '2025-10-01', '2025-11-01', '2024-04-01', '2024-05-01', '2024-06-01',
#  '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01',
#  '2024-12-01', '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01']
# Length: 35, dtype: str
