# %%
import os
from pyspark.sql import SparkSession
import utils.bronze_preprocess as bp

# %%
def create_session():
    spk = SparkSession.builder \
        .appName('EDA') \
        .getOrCreate()
    return spk

# %%
spark = create_session()

# %%
df = spk.read.parquet('data/bronze/lms_loan_daily/lms_loan_daily_2023-01-01/')
df.show(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = spk.read.parquet('data/bronze/lms_loan_daily/lms_loan_daily_2023-01-01/')
#       2 df.show(5)
#
# NameError: name 'spk' is not defined
